# %%
cd /
# Out:
# /

# %%
cd content/drive/MyDrive/DL\ Project/Data
# Out:
# [Errno 2] No such file or directory: 'content/drive/MyDrive/DL Project/Data'
# /

# %%
# !wget https://dl.challenge.zalo.ai/traffic-sign-detection/data/za_traffic_2020.zip
# Out:
# --2020-12-29 02:49:49--  https://dl.challenge.zalo.ai/traffic-sign-detection/data/za_traffic_2020.zip
# Resolving dl.challenge.zalo.ai (dl.challenge.zalo.ai)... 49.213.78.231
# Connecting to dl.challenge.zalo.ai (dl.challenge.zalo.ai)|49.213.78.231|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6076245575 (5.7G) [application/zip]
# Saving to: ‘za_traffic_2020.zip’
#
# za_traffic_2020.zip 100%[===================>]   5.66G  16.5MB/s    in 6m 6s
#
# 2020-12-29 02:55:56 (15.8 MB/s) - ‘za_traffic_2020.zip’ saved [6076245575/6076245575]

# %%
# !wget https://dl.challenge.zalo.ai/traffic-sign-detection/data/traffic_private.zip
# Out:
# --2020-12-29 02:57:30--  https://dl.challenge.zalo.ai/traffic-sign-detection/data/traffic_private.zip
# Resolving dl.challenge.zalo.ai (dl.challenge.zalo.ai)... 49.213.78.231
# Connecting to dl.challenge.zalo.ai (dl.challenge.zalo.ai)|49.213.78.231|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3206190504 (3.0G) [application/zip]
# Saving to: ‘traffic_private.zip’
#
# traffic_private.zip 100%[===================>]   2.99G  15.4MB/s    in 3m 14s
#
# 2020-12-29 03:00:45 (15.8 MB/s) - ‘traffic_private.zip’ saved [3206190504/3206190504]

# %%
# !unzip za_traffic_2020.zip -d Training

# %%
ls
# Out:
# bin/      dev/   lib32/  opt/   sbin/   tensorflow-1.15.2/   usr/
# boot/     etc/   lib64/  proc/  srv/    tmp/                 var/
# content/  home/  media/  root/  swift/  tools/
# datalab/  lib/   mnt/    run/   sys/    traffic_private.zip

# %%
# !unzip traffic_private.zip
# Out:
# Archive:  traffic_private.zip
# replace traffic_private/images/11101.png? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
ls
# Out:
# bin/      dev/   lib32/  opt/   sbin/   tensorflow-1.15.2/  traffic_private.zip
# boot/     etc/   lib64/  proc/  srv/    tmp/                usr/
# content/  home/  media/  root/  swift/  tools/              var/
# datalab/  lib/   mnt/    run/   sys/    traffic_private/

# %%
# !unzip traffic_private.zip -d content/drive/MyDrive/DL\ Project/Data

# %%
ls
# Out:
# bin/      dev/   lib32/  opt/   sbin/   tensorflow-1.15.2/  traffic_private.zip
# boot/     etc/   lib64/  proc/  srv/    tmp/                usr/
# content/  home/  media/  root/  swift/  tools/              var/
# datalab/  lib/   mnt/    run/   sys/    traffic_private/
